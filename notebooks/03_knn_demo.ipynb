# %% [markdown]
# # K-Nearest Neighbors (KNN) from Scratch
#
# This notebook demonstrates the K-Nearest Neighbors algorithm for classification.

# %%
import sys
import os
sys.path.append(os.path.abspath(".."))

import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification

from ml_scratch.neighbors.knn import KNN
from ml_scratch.metrics import accuracy_score

# %%
X, y = make_classification(
    n_samples=200,
    n_features=2,
    n_redundant=0,
    n_informative=2,
    random_state=42
)

model = KNN(k=5)
model.fit(X, y)

y_pred = model.predict(X)
acc = accuracy_score(y, y_pred)
print("Accuracy:", acc)
# Out:
# Accuracy: 0.91

# %% [markdown]
# ## Decision Boundary

# %%
xx, yy = np.meshgrid(
    np.linspace(X[:, 0].min() - 1, X[:, 0].max() + 1, 200),
    np.linspace(X[:, 1].min() - 1, X[:, 1].max() + 1, 200)
)

grid = np.c_[xx.ravel(), yy.ravel()]
Z = model.predict(grid).reshape(xx.shape)

plt.figure(figsize=(8, 5))
plt.contourf(xx, yy, Z, alpha=0.3)
plt.scatter(X[:, 0], X[:, 1], c=y)
plt.title("KNN Decision Boundary")
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.show()

# %% [markdown]
# ## Conclusion
#
# - KNN is a simple instance-based learning algorithm.
# - It does not explicitly train parameters.
# - Predictions depend on the local structure of the data.
